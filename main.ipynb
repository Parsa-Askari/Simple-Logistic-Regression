# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv("./IRIS.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
enc=LabelEncoder()
df["species"]=enc.fit_transform(df["species"])
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
import model
from importlib import reload
reload(model)
X,Y=df.drop(columns=["species"]),df["species"]
X=X.to_numpy()
Y=Y.to_numpy()
Model=model.LogisticRegression()
Model.Train(X=X,Y=Y,with_valid=True,lr=0.01,class_num=3,epochs=100)
# Out:
# ...
# train loss :  1.3088324354656538
# valid loss :  0.7753862723509236
# ...
# train loss :  0.9181289199624034
# valid loss :  0.8555906008185394
# ...
# train loss :  1.221363017097125
# valid loss :  1.0616085749779294
# ...
# train loss :  0.8303600750622733
# valid loss :  0.7869922084469424
# ...
# train loss :  0.5705918358197013
# valid loss :  0.6696655910517757
# ...
# train loss :  0.5565867873825546
# valid loss :  0.5226462440470145
# ...
# train loss :  0.5607294608239526
# valid loss :  0.7598652959344815
# ...
# train loss :  0.7437855180396816
# valid loss :  0.6577837223009666
# ...
# train loss :  0.579662626426097
# valid loss :  0.5911404283900401
# ...
# train loss :  0.693168722431028
# valid loss :  0.6327748791185624
# ...
# train loss :  0.4636365570778402
# valid loss :  0.42180842168327864
# ...
# train loss :  0.8632258723886871
# valid loss :  0.5609895890154156
# ...
# train loss :  0.46973900632673454
# valid loss :  0.5103734838409626
# ...
# train loss :  0.5126639705835836
# valid loss :  0.5416196680048222
# ...

# %%
import matplotlib.pyplot as plt
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(Model.loss_history["train"],label="train loss",color="green")
ax.plot(Model.loss_history["val"],label="valid loss",color="red")
ax.set_xlabel("epochs")
ax.set_ylabel("loss")
ax.legend()
